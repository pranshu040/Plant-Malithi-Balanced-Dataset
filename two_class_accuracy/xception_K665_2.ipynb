# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd

# %%
# -------------------------------
# Parameters
# -------------------------------
img_height, img_width = 224, 224
batch_size = 32
max_epochs = 300  # Maximum training epochs

# Adam optimizer parameters
learning_rate = 1e-4
beta_1 = 0.9
beta_2 = 0.999
epsilon = 1e-7

# Early stopping to prevent overfitting
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

# %%
# -------------------------------
# Paths & Filter Selection
# -------------------------------
dataset_path = "/kaggle/input/new-data/Balanced_dataset_augmented_new"
filter_name = "K665_balance"  # Change filter if needed

# Define two classes: Healthy and Diseased
classes = ["healthy", "diseased"]  # Matching your folder structure

# Construct dataset paths
filter_path = os.path.join(dataset_path, filter_name)
train_dir = os.path.join(filter_path, 'train')
validation_dir = os.path.join(filter_path, 'validation')
test_dir = os.path.join(filter_path, 'test')

# %%
# -------------------------------
# Data Generators
# -------------------------------
datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',  # Binary classification
    color_mode='rgb',  # Ensure all images are RGB
    shuffle=True
)

validation_generator = datagen.flow_from_directory(
    validation_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',  # Binary classification
    color_mode='rgb',
    shuffle=False
)

test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',  # Binary classification
    color_mode='rgb',
    shuffle=False
)
# Out:
# Found 2121 images belonging to 2 classes.
# Found 267 images belonging to 2 classes.
# Found 264 images belonging to 2 classes.

# %%
# -------------------------------
# Build the Xception Model
# -------------------------------
base_model = Xception(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom classification head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)  # Dropout for regularization
predictions = Dense(1, activation='sigmoid')(x)  # Single neuron for binary classification
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Create the full model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1 (Conv2D)     │ (None, 111, 111, 32)   │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1_bn           │ (None, 111, 111, 32)   │            128 │ block1_conv1[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1_act          │ (None, 111, 111, 32)   │              0 │ block1_conv1_bn[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2 (Conv2D)     │ (None, 109, 109, 64)   │         18,432 │ block1_conv1_act[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2_bn           │ (None, 109, 109, 64)   │            256 │ block1_conv2[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2_act          │ (None, 109, 109, 64)   │              0 │ block1_conv2_bn[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv1           │ (None, 109, 109, 128)  │          8,768 │ block1_conv2_act[0][0] │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv1_bn        │ (None, 109, 109, 128)  │            512 │ block2_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv2_act       │ (None, 109, 109, 128)  │              0 │ block2_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv2           │ (None, 109, 109, 128)  │         17,536 │ block2_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv2_bn        │ (None, 109, 109, 128)  │            512 │ block2_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 55, 55, 128)    │          8,192 │ block1_conv2_act[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_pool               │ (None, 55, 55, 128)    │              0 │ block2_sepconv2_bn[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 55, 55, 128)    │            512 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 55, 55, 128)    │              0 │ block2_pool[0][0],     │
# │                           │                        │                │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv1_act       │ (None, 55, 55, 128)    │              0 │ add[0][0]              │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv1           │ (None, 55, 55, 256)    │         33,920 │ block3_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv1_bn        │ (None, 55, 55, 256)    │          1,024 │ block3_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv2_act       │ (None, 55, 55, 256)    │              0 │ block3_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv2           │ (None, 55, 55, 256)    │         67,840 │ block3_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv2_bn        │ (None, 55, 55, 256)    │          1,024 │ block3_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 28, 28, 256)    │         32,768 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_pool               │ (None, 28, 28, 256)    │              0 │ block3_sepconv2_bn[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 28, 28, 256)    │          1,024 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 28, 28, 256)    │              0 │ block3_pool[0][0],     │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv1_act       │ (None, 28, 28, 256)    │              0 │ add_1[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv1           │ (None, 28, 28, 728)    │        188,672 │ block4_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv1_bn        │ (None, 28, 28, 728)    │          2,912 │ block4_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv2_act       │ (None, 28, 28, 728)    │              0 │ block4_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv2           │ (None, 28, 28, 728)    │        536,536 │ block4_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv2_bn        │ (None, 28, 28, 728)    │          2,912 │ block4_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 14, 14, 728)    │        186,368 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_pool               │ (None, 14, 14, 728)    │              0 │ block4_sepconv2_bn[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 14, 14, 728)    │          2,912 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 14, 14, 728)    │              0 │ block4_pool[0][0],     │
# │                           │                        │                │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block5_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block5_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block5_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block5_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block5_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block5_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block5_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block5_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 14, 14, 728)    │              0 │ block5_sepconv3_bn[0]… │
# │                           │                        │                │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_3[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block6_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block6_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block6_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block6_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block6_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block6_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block6_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block6_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 14, 14, 728)    │              0 │ block6_sepconv3_bn[0]… │
# │                           │                        │                │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block7_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block7_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block7_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block7_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block7_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block7_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block7_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block7_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 14, 14, 728)    │              0 │ block7_sepconv3_bn[0]… │
# │                           │                        │                │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block8_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block8_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block8_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block8_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block8_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block8_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block8_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block8_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 14, 14, 728)    │              0 │ block8_sepconv3_bn[0]… │
# │                           │                        │                │ add_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_6[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block9_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block9_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block9_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block9_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block9_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block9_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block9_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block9_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 14, 14, 728)    │              0 │ block9_sepconv3_bn[0]… │
# │                           │                        │                │ add_6[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_7[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block10_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block10_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block10_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv2          │ (None, 14, 14, 728)    │        536,536 │ block10_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv2_bn       │ (None, 14, 14, 728)    │          2,912 │ block10_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv3_act      │ (None, 14, 14, 728)    │              0 │ block10_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv3          │ (None, 14, 14, 728)    │        536,536 │ block10_sepconv3_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv3_bn       │ (None, 14, 14, 728)    │          2,912 │ block10_sepconv3[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 14, 14, 728)    │              0 │ block10_sepconv3_bn[0… │
# │                           │                        │                │ add_7[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_8[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block11_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block11_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block11_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv2          │ (None, 14, 14, 728)    │        536,536 │ block11_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv2_bn       │ (None, 14, 14, 728)    │          2,912 │ block11_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv3_act      │ (None, 14, 14, 728)    │              0 │ block11_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv3          │ (None, 14, 14, 728)    │        536,536 │ block11_sepconv3_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv3_bn       │ (None, 14, 14, 728)    │          2,912 │ block11_sepconv3[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 14, 14, 728)    │              0 │ block11_sepconv3_bn[0… │
# │                           │                        │                │ add_8[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_9[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block12_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block12_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block12_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv2          │ (None, 14, 14, 728)    │        536,536 │ block12_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv2_bn       │ (None, 14, 14, 728)    │          2,912 │ block12_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv3_act      │ (None, 14, 14, 728)    │              0 │ block12_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv3          │ (None, 14, 14, 728)    │        536,536 │ block12_sepconv3_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv3_bn       │ (None, 14, 14, 728)    │          2,912 │ block12_sepconv3[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 14, 14, 728)    │              0 │ block12_sepconv3_bn[0… │
# │                           │                        │                │ add_9[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_10[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block13_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block13_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block13_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv2          │ (None, 14, 14, 1024)   │        752,024 │ block13_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv2_bn       │ (None, 14, 14, 1024)   │          4,096 │ block13_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 7, 7, 1024)     │        745,472 │ add_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_pool              │ (None, 7, 7, 1024)     │              0 │ block13_sepconv2_bn[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 7, 7, 1024)     │          4,096 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 7, 7, 1024)     │              0 │ block13_pool[0][0],    │
# │                           │                        │                │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv1          │ (None, 7, 7, 1536)     │      1,582,080 │ add_11[0][0]           │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv1_bn       │ (None, 7, 7, 1536)     │          6,144 │ block14_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv1_act      │ (None, 7, 7, 1536)     │              0 │ block14_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv2          │ (None, 7, 7, 2048)     │      3,159,552 │ block14_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv2_bn       │ (None, 7, 7, 2048)     │          8,192 │ block14_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv2_act      │ (None, 7, 7, 2048)     │              0 │ block14_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 2048)           │              0 │ block14_sepconv2_act[… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 2048)           │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1)              │          2,049 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 20,863,529 (79.59 MB)
#  Trainable params: 2,049 (8.00 KB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# -------------------------------
# Train the Model
# -------------------------------
history = model.fit(
    train_generator,
    epochs=max_epochs,
    validation_data=validation_generator,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/300
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 45s 431ms/step - accuracy: 0.4853 - loss: 0.7295 - val_accuracy: 0.5955 - val_loss: 0.6828
# Epoch 2/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - accuracy: 0.5413 - loss: 0.6857 - val_accuracy: 0.6105 - val_loss: 0.6668
# Epoch 3/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.5741 - loss: 0.6801 - val_accuracy: 0.6217 - val_loss: 0.6531
# Epoch 4/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - accuracy: 0.5929 - loss: 0.6629 - val_accuracy: 0.6517 - val_loss: 0.6413
# Epoch 5/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 123ms/step - accuracy: 0.6358 - loss: 0.6451 - val_accuracy: 0.6667 - val_loss: 0.6311
# Epoch 6/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - accuracy: 0.6425 - loss: 0.6392 - val_accuracy: 0.6742 - val_loss: 0.6225
# Epoch 7/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.6526 - loss: 0.6342 - val_accuracy: 0.6854 - val_loss: 0.6151
# Epoch 8/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.6981 - loss: 0.6103 - val_accuracy: 0.6929 - val_loss: 0.6077
# Epoch 9/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.6859 - loss: 0.6088 - val_accuracy: 0.7041 - val_loss: 0.6015
# Epoch 10/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.6928 - loss: 0.6026 - val_accuracy: 0.7041 - val_loss: 0.5961
# Epoch 11/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.6969 - loss: 0.5977 - val_accuracy: 0.7079 - val_loss: 0.5908
# Epoch 12/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.6858 - loss: 0.5948 - val_accuracy: 0.7116 - val_loss: 0.5860
# Epoch 13/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.6906 - loss: 0.5889 - val_accuracy: 0.7116 - val_loss: 0.5816
# Epoch 14/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - accuracy: 0.7029 - loss: 0.5734 - val_accuracy: 0.7341 - val_loss: 0.5781
# Epoch 15/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7105 - loss: 0.5778 - val_accuracy: 0.7416 - val_loss: 0.5740
# Epoch 16/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.6917 - loss: 0.5800 - val_accuracy: 0.7341 - val_loss: 0.5702
# Epoch 17/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.7206 - loss: 0.5579 - val_accuracy: 0.7491 - val_loss: 0.5667
# Epoch 18/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.7075 - loss: 0.5710 - val_accuracy: 0.7491 - val_loss: 0.5638
# Epoch 19/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7218 - loss: 0.5630 - val_accuracy: 0.7528 - val_loss: 0.5609
# Epoch 20/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7224 - loss: 0.5613 - val_accuracy: 0.7528 - val_loss: 0.5582
# Epoch 21/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7463 - loss: 0.5458 - val_accuracy: 0.7528 - val_loss: 0.5552
# Epoch 22/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7326 - loss: 0.5463 - val_accuracy: 0.7528 - val_loss: 0.5530
# Epoch 23/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7159 - loss: 0.5479 - val_accuracy: 0.7491 - val_loss: 0.5507
# Epoch 24/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7163 - loss: 0.5503 - val_accuracy: 0.7528 - val_loss: 0.5483
# Epoch 25/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7500 - loss: 0.5336 - val_accuracy: 0.7528 - val_loss: 0.5460
# Epoch 26/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7401 - loss: 0.5524 - val_accuracy: 0.7566 - val_loss: 0.5439
# Epoch 27/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7312 - loss: 0.5426 - val_accuracy: 0.7528 - val_loss: 0.5420
# Epoch 28/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.7561 - loss: 0.5206 - val_accuracy: 0.7528 - val_loss: 0.5398
# Epoch 29/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7335 - loss: 0.5419 - val_accuracy: 0.7566 - val_loss: 0.5379
# Epoch 30/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7346 - loss: 0.5412 - val_accuracy: 0.7566 - val_loss: 0.5362
# Epoch 31/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - accuracy: 0.7551 - loss: 0.5263 - val_accuracy: 0.7603 - val_loss: 0.5344
# Epoch 32/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7279 - loss: 0.5399 - val_accuracy: 0.7603 - val_loss: 0.5329
# Epoch 33/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7254 - loss: 0.5351 - val_accuracy: 0.7603 - val_loss: 0.5309
# Epoch 34/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.7360 - loss: 0.5384 - val_accuracy: 0.7566 - val_loss: 0.5296
# Epoch 35/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.7584 - loss: 0.5275 - val_accuracy: 0.7640 - val_loss: 0.5281
# Epoch 36/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7409 - loss: 0.5188 - val_accuracy: 0.7678 - val_loss: 0.5268
# Epoch 37/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7717 - loss: 0.5170 - val_accuracy: 0.7678 - val_loss: 0.5254
# Epoch 38/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7608 - loss: 0.5148 - val_accuracy: 0.7603 - val_loss: 0.5235
# Epoch 39/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7444 - loss: 0.5225 - val_accuracy: 0.7603 - val_loss: 0.5224
# Epoch 40/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7351 - loss: 0.5150 - val_accuracy: 0.7603 - val_loss: 0.5212
# Epoch 41/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7568 - loss: 0.5228 - val_accuracy: 0.7603 - val_loss: 0.5198
# Epoch 42/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7338 - loss: 0.5301 - val_accuracy: 0.7603 - val_loss: 0.5185
# Epoch 43/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7615 - loss: 0.5141 - val_accuracy: 0.7715 - val_loss: 0.5175
# Epoch 44/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7740 - loss: 0.5008 - val_accuracy: 0.7678 - val_loss: 0.5167
# Epoch 45/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7599 - loss: 0.5143 - val_accuracy: 0.7640 - val_loss: 0.5146
# Epoch 46/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7354 - loss: 0.5149 - val_accuracy: 0.7640 - val_loss: 0.5133
# Epoch 47/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7660 - loss: 0.4993 - val_accuracy: 0.7603 - val_loss: 0.5121
# Epoch 48/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.7651 - loss: 0.4941 - val_accuracy: 0.7640 - val_loss: 0.5108
# Epoch 49/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7629 - loss: 0.5014 - val_accuracy: 0.7640 - val_loss: 0.5098
# Epoch 50/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7633 - loss: 0.5082 - val_accuracy: 0.7640 - val_loss: 0.5092
# Epoch 51/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.7752 - loss: 0.4998 - val_accuracy: 0.7678 - val_loss: 0.5081
# Epoch 52/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7771 - loss: 0.4874 - val_accuracy: 0.7640 - val_loss: 0.5068
# Epoch 53/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7854 - loss: 0.4913 - val_accuracy: 0.7715 - val_loss: 0.5056
# Epoch 54/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7770 - loss: 0.4936 - val_accuracy: 0.7640 - val_loss: 0.5046
# Epoch 55/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7502 - loss: 0.5055 - val_accuracy: 0.7678 - val_loss: 0.5035
# Epoch 56/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7527 - loss: 0.5009 - val_accuracy: 0.7678 - val_loss: 0.5023
# Epoch 57/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7851 - loss: 0.4884 - val_accuracy: 0.7678 - val_loss: 0.5013
# Epoch 58/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7688 - loss: 0.4927 - val_accuracy: 0.7678 - val_loss: 0.5005
# Epoch 59/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7673 - loss: 0.4949 - val_accuracy: 0.7678 - val_loss: 0.4995
# Epoch 60/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7848 - loss: 0.4901 - val_accuracy: 0.7678 - val_loss: 0.4984
# Epoch 61/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7889 - loss: 0.4707 - val_accuracy: 0.7678 - val_loss: 0.4974
# Epoch 62/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7839 - loss: 0.4756 - val_accuracy: 0.7715 - val_loss: 0.4968
# Epoch 63/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7745 - loss: 0.4849 - val_accuracy: 0.7715 - val_loss: 0.4959
# Epoch 64/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7753 - loss: 0.4974 - val_accuracy: 0.7715 - val_loss: 0.4948
# Epoch 65/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7844 - loss: 0.4786 - val_accuracy: 0.7715 - val_loss: 0.4937
# Epoch 66/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7566 - loss: 0.4939 - val_accuracy: 0.7715 - val_loss: 0.4928
# Epoch 67/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7697 - loss: 0.4916 - val_accuracy: 0.7753 - val_loss: 0.4923
# Epoch 68/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7707 - loss: 0.4894 - val_accuracy: 0.7715 - val_loss: 0.4911
# Epoch 69/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7649 - loss: 0.4934 - val_accuracy: 0.7753 - val_loss: 0.4903
# Epoch 70/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7581 - loss: 0.4913 - val_accuracy: 0.7753 - val_loss: 0.4892
# Epoch 71/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7578 - loss: 0.4922 - val_accuracy: 0.7753 - val_loss: 0.4887
# Epoch 72/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7666 - loss: 0.4877 - val_accuracy: 0.7790 - val_loss: 0.4877
# Epoch 73/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7781 - loss: 0.4747 - val_accuracy: 0.7790 - val_loss: 0.4871
# Epoch 74/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7896 - loss: 0.4691 - val_accuracy: 0.7828 - val_loss: 0.4861
# Epoch 75/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7856 - loss: 0.4662 - val_accuracy: 0.7790 - val_loss: 0.4855
# Epoch 76/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7587 - loss: 0.4837 - val_accuracy: 0.7790 - val_loss: 0.4845
# Epoch 77/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7807 - loss: 0.4616 - val_accuracy: 0.7828 - val_loss: 0.4839
# Epoch 78/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7729 - loss: 0.4769 - val_accuracy: 0.7865 - val_loss: 0.4835
# Epoch 79/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7691 - loss: 0.4918 - val_accuracy: 0.7865 - val_loss: 0.4826
# Epoch 80/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7866 - loss: 0.4723 - val_accuracy: 0.7790 - val_loss: 0.4820
# Epoch 81/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7719 - loss: 0.4699 - val_accuracy: 0.7790 - val_loss: 0.4813
# Epoch 82/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7862 - loss: 0.4597 - val_accuracy: 0.7828 - val_loss: 0.4807
# Epoch 83/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7768 - loss: 0.4758 - val_accuracy: 0.7828 - val_loss: 0.4798
# Epoch 84/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7711 - loss: 0.4757 - val_accuracy: 0.7903 - val_loss: 0.4790
# Epoch 85/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7826 - loss: 0.4607 - val_accuracy: 0.7828 - val_loss: 0.4782
# Epoch 86/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - accuracy: 0.8016 - loss: 0.4498 - val_accuracy: 0.7828 - val_loss: 0.4782
# Epoch 87/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7885 - loss: 0.4670 - val_accuracy: 0.7865 - val_loss: 0.4769
# Epoch 88/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7761 - loss: 0.4878 - val_accuracy: 0.7865 - val_loss: 0.4765
# Epoch 89/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7913 - loss: 0.4563 - val_accuracy: 0.7865 - val_loss: 0.4759
# Epoch 90/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7978 - loss: 0.4606 - val_accuracy: 0.7865 - val_loss: 0.4747
# Epoch 91/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7954 - loss: 0.4609 - val_accuracy: 0.7903 - val_loss: 0.4742
# Epoch 92/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7948 - loss: 0.4643 - val_accuracy: 0.7865 - val_loss: 0.4737
# Epoch 93/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7781 - loss: 0.4632 - val_accuracy: 0.7865 - val_loss: 0.4732
# Epoch 94/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7962 - loss: 0.4563 - val_accuracy: 0.7940 - val_loss: 0.4724
# Epoch 95/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7903 - loss: 0.4512 - val_accuracy: 0.7940 - val_loss: 0.4718
# Epoch 96/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7992 - loss: 0.4510 - val_accuracy: 0.7865 - val_loss: 0.4715
# Epoch 97/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7750 - loss: 0.4736 - val_accuracy: 0.7940 - val_loss: 0.4709
# Epoch 98/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7939 - loss: 0.4550 - val_accuracy: 0.7903 - val_loss: 0.4706
# Epoch 99/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8033 - loss: 0.4473 - val_accuracy: 0.7940 - val_loss: 0.4699
# Epoch 100/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7912 - loss: 0.4645 - val_accuracy: 0.7940 - val_loss: 0.4694
# Epoch 101/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8065 - loss: 0.4346 - val_accuracy: 0.7903 - val_loss: 0.4692
# Epoch 102/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7748 - loss: 0.4618 - val_accuracy: 0.7903 - val_loss: 0.4684
# Epoch 103/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7919 - loss: 0.4627 - val_accuracy: 0.7940 - val_loss: 0.4680
# Epoch 104/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8050 - loss: 0.4471 - val_accuracy: 0.7940 - val_loss: 0.4673
# Epoch 105/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7898 - loss: 0.4577 - val_accuracy: 0.7903 - val_loss: 0.4669
# Epoch 106/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.7967 - loss: 0.4555 - val_accuracy: 0.7940 - val_loss: 0.4669
# Epoch 107/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7945 - loss: 0.4626 - val_accuracy: 0.7903 - val_loss: 0.4659
# Epoch 108/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7867 - loss: 0.4531 - val_accuracy: 0.8015 - val_loss: 0.4655
# Epoch 109/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7994 - loss: 0.4541 - val_accuracy: 0.7978 - val_loss: 0.4651
# Epoch 110/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7788 - loss: 0.4608 - val_accuracy: 0.7903 - val_loss: 0.4645
# Epoch 111/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7922 - loss: 0.4566 - val_accuracy: 0.8015 - val_loss: 0.4640
# Epoch 112/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7947 - loss: 0.4473 - val_accuracy: 0.7903 - val_loss: 0.4629
# Epoch 113/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7987 - loss: 0.4523 - val_accuracy: 0.7903 - val_loss: 0.4628
# Epoch 114/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8141 - loss: 0.4251 - val_accuracy: 0.7903 - val_loss: 0.4622
# Epoch 115/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8102 - loss: 0.4463 - val_accuracy: 0.8015 - val_loss: 0.4620
# Epoch 116/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8063 - loss: 0.4440 - val_accuracy: 0.7940 - val_loss: 0.4614
# Epoch 117/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7986 - loss: 0.4513 - val_accuracy: 0.7978 - val_loss: 0.4610
# Epoch 118/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.7966 - loss: 0.4554 - val_accuracy: 0.7903 - val_loss: 0.4604
# Epoch 119/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.8160 - loss: 0.4340 - val_accuracy: 0.7978 - val_loss: 0.4599
# Epoch 120/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7860 - loss: 0.4545 - val_accuracy: 0.7865 - val_loss: 0.4593
# Epoch 121/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7837 - loss: 0.4431 - val_accuracy: 0.8015 - val_loss: 0.4587
# Epoch 122/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7997 - loss: 0.4455 - val_accuracy: 0.7978 - val_loss: 0.4583
# Epoch 123/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8017 - loss: 0.4379 - val_accuracy: 0.8015 - val_loss: 0.4582
# Epoch 124/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.8113 - loss: 0.4333 - val_accuracy: 0.7978 - val_loss: 0.4573
# Epoch 125/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7942 - loss: 0.4487 - val_accuracy: 0.7940 - val_loss: 0.4569
# Epoch 126/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8053 - loss: 0.4304 - val_accuracy: 0.7903 - val_loss: 0.4565
# Epoch 127/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7922 - loss: 0.4700 - val_accuracy: 0.7940 - val_loss: 0.4562
# Epoch 128/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8042 - loss: 0.4441 - val_accuracy: 0.7903 - val_loss: 0.4557
# Epoch 129/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7946 - loss: 0.4354 - val_accuracy: 0.7978 - val_loss: 0.4556
# Epoch 130/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7701 - loss: 0.4719 - val_accuracy: 0.7978 - val_loss: 0.4550
# Epoch 131/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7967 - loss: 0.4368 - val_accuracy: 0.7903 - val_loss: 0.4547
# Epoch 132/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8051 - loss: 0.4510 - val_accuracy: 0.7940 - val_loss: 0.4544
# Epoch 133/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8081 - loss: 0.4459 - val_accuracy: 0.8015 - val_loss: 0.4541
# Epoch 134/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8137 - loss: 0.4255 - val_accuracy: 0.7940 - val_loss: 0.4535
# Epoch 135/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8131 - loss: 0.4311 - val_accuracy: 0.7978 - val_loss: 0.4531
# Epoch 136/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8022 - loss: 0.4330 - val_accuracy: 0.7978 - val_loss: 0.4526
# Epoch 137/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.7872 - loss: 0.4477 - val_accuracy: 0.7978 - val_loss: 0.4520
# Epoch 138/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7845 - loss: 0.4437 - val_accuracy: 0.7978 - val_loss: 0.4519
# Epoch 139/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7925 - loss: 0.4488 - val_accuracy: 0.7940 - val_loss: 0.4515
# Epoch 140/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8021 - loss: 0.4442 - val_accuracy: 0.7978 - val_loss: 0.4513
# Epoch 141/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7911 - loss: 0.4476 - val_accuracy: 0.7940 - val_loss: 0.4508
# Epoch 142/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8031 - loss: 0.4383 - val_accuracy: 0.7978 - val_loss: 0.4503
# Epoch 143/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8227 - loss: 0.4245 - val_accuracy: 0.7978 - val_loss: 0.4501
# Epoch 144/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8038 - loss: 0.4459 - val_accuracy: 0.7978 - val_loss: 0.4498
# Epoch 145/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8075 - loss: 0.4333 - val_accuracy: 0.7978 - val_loss: 0.4492
# Epoch 146/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8007 - loss: 0.4363 - val_accuracy: 0.7978 - val_loss: 0.4491
# Epoch 147/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8200 - loss: 0.4200 - val_accuracy: 0.7940 - val_loss: 0.4488
# Epoch 148/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8199 - loss: 0.4252 - val_accuracy: 0.7940 - val_loss: 0.4486
# Epoch 149/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7945 - loss: 0.4396 - val_accuracy: 0.7978 - val_loss: 0.4479
# Epoch 150/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8045 - loss: 0.4326 - val_accuracy: 0.7978 - val_loss: 0.4479
# Epoch 151/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7998 - loss: 0.4423 - val_accuracy: 0.7978 - val_loss: 0.4470
# Epoch 152/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8057 - loss: 0.4370 - val_accuracy: 0.7978 - val_loss: 0.4465
# Epoch 153/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8026 - loss: 0.4316 - val_accuracy: 0.7978 - val_loss: 0.4460
# Epoch 154/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7906 - loss: 0.4451 - val_accuracy: 0.7978 - val_loss: 0.4461
# Epoch 155/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - accuracy: 0.8072 - loss: 0.4387 - val_accuracy: 0.7978 - val_loss: 0.4459
# Epoch 156/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8187 - loss: 0.4141 - val_accuracy: 0.7940 - val_loss: 0.4451
# Epoch 157/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7984 - loss: 0.4388 - val_accuracy: 0.8015 - val_loss: 0.4448
# Epoch 158/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8055 - loss: 0.4364 - val_accuracy: 0.8015 - val_loss: 0.4445
# Epoch 159/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8004 - loss: 0.4365 - val_accuracy: 0.7978 - val_loss: 0.4445
# Epoch 160/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7990 - loss: 0.4414 - val_accuracy: 0.8015 - val_loss: 0.4438
# Epoch 161/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8107 - loss: 0.4252 - val_accuracy: 0.7978 - val_loss: 0.4433
# Epoch 162/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8135 - loss: 0.4257 - val_accuracy: 0.8015 - val_loss: 0.4429
# Epoch 163/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8213 - loss: 0.4178 - val_accuracy: 0.7978 - val_loss: 0.4427
# Epoch 164/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8243 - loss: 0.4267 - val_accuracy: 0.8015 - val_loss: 0.4421
# Epoch 165/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8082 - loss: 0.4272 - val_accuracy: 0.7978 - val_loss: 0.4429
# Epoch 166/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8063 - loss: 0.4386 - val_accuracy: 0.8015 - val_loss: 0.4416
# Epoch 167/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8002 - loss: 0.4400 - val_accuracy: 0.8015 - val_loss: 0.4410
# Epoch 168/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8159 - loss: 0.4221 - val_accuracy: 0.7978 - val_loss: 0.4412
# Epoch 169/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7945 - loss: 0.4433 - val_accuracy: 0.8015 - val_loss: 0.4405
# Epoch 170/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8115 - loss: 0.4300 - val_accuracy: 0.8015 - val_loss: 0.4402
# Epoch 171/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8094 - loss: 0.4297 - val_accuracy: 0.7978 - val_loss: 0.4404
# Epoch 172/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7930 - loss: 0.4418 - val_accuracy: 0.8015 - val_loss: 0.4399
# Epoch 173/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8179 - loss: 0.4215 - val_accuracy: 0.8015 - val_loss: 0.4394
# Epoch 174/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8095 - loss: 0.4208 - val_accuracy: 0.8015 - val_loss: 0.4391
# Epoch 175/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8080 - loss: 0.4260 - val_accuracy: 0.8015 - val_loss: 0.4390
# Epoch 176/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8000 - loss: 0.4300 - val_accuracy: 0.8015 - val_loss: 0.4385
# Epoch 177/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7878 - loss: 0.4365 - val_accuracy: 0.8015 - val_loss: 0.4381
# Epoch 178/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8079 - loss: 0.4209 - val_accuracy: 0.8015 - val_loss: 0.4380
# Epoch 179/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8124 - loss: 0.4338 - val_accuracy: 0.8015 - val_loss: 0.4378
# Epoch 180/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8109 - loss: 0.4271 - val_accuracy: 0.8015 - val_loss: 0.4376
# Epoch 181/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8013 - loss: 0.4372 - val_accuracy: 0.8015 - val_loss: 0.4376
# Epoch 182/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.7979 - loss: 0.4359 - val_accuracy: 0.8015 - val_loss: 0.4374
# Epoch 183/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8279 - loss: 0.4120 - val_accuracy: 0.8052 - val_loss: 0.4367
# Epoch 184/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8275 - loss: 0.4086 - val_accuracy: 0.8015 - val_loss: 0.4366
# Epoch 185/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8225 - loss: 0.4211 - val_accuracy: 0.8015 - val_loss: 0.4367
# Epoch 186/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8131 - loss: 0.4372 - val_accuracy: 0.8015 - val_loss: 0.4363
# Epoch 187/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7999 - loss: 0.4298 - val_accuracy: 0.8015 - val_loss: 0.4362
# Epoch 188/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8169 - loss: 0.4206 - val_accuracy: 0.8015 - val_loss: 0.4359
# Epoch 189/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8194 - loss: 0.4181 - val_accuracy: 0.8015 - val_loss: 0.4359
# Epoch 190/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8236 - loss: 0.4089 - val_accuracy: 0.8052 - val_loss: 0.4352
# Epoch 191/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8027 - loss: 0.4308 - val_accuracy: 0.7940 - val_loss: 0.4357
# Epoch 192/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8037 - loss: 0.4332 - val_accuracy: 0.8015 - val_loss: 0.4346
# Epoch 193/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8073 - loss: 0.4260 - val_accuracy: 0.8015 - val_loss: 0.4347
# Epoch 194/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8236 - loss: 0.4175 - val_accuracy: 0.8015 - val_loss: 0.4341
# Epoch 195/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8025 - loss: 0.4273 - val_accuracy: 0.8015 - val_loss: 0.4343
# Epoch 196/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8047 - loss: 0.4323 - val_accuracy: 0.8015 - val_loss: 0.4341
# Epoch 197/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - accuracy: 0.8103 - loss: 0.4118 - val_accuracy: 0.7978 - val_loss: 0.4341
# Epoch 198/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8191 - loss: 0.4362 - val_accuracy: 0.8015 - val_loss: 0.4336
# Epoch 199/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - accuracy: 0.8285 - loss: 0.4152 - val_accuracy: 0.8052 - val_loss: 0.4328
# Epoch 200/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8153 - loss: 0.4203 - val_accuracy: 0.8052 - val_loss: 0.4324
# Epoch 201/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8085 - loss: 0.4227 - val_accuracy: 0.8015 - val_loss: 0.4322
# Epoch 202/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8047 - loss: 0.4228 - val_accuracy: 0.8015 - val_loss: 0.4322
# Epoch 203/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8189 - loss: 0.4120 - val_accuracy: 0.8052 - val_loss: 0.4319
# Epoch 204/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8240 - loss: 0.4042 - val_accuracy: 0.7978 - val_loss: 0.4317
# Epoch 205/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8124 - loss: 0.4142 - val_accuracy: 0.7978 - val_loss: 0.4320
# Epoch 206/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7921 - loss: 0.4376 - val_accuracy: 0.7978 - val_loss: 0.4314
# Epoch 207/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8173 - loss: 0.4279 - val_accuracy: 0.8015 - val_loss: 0.4313
# Epoch 208/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8208 - loss: 0.4005 - val_accuracy: 0.7978 - val_loss: 0.4306
# Epoch 209/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8074 - loss: 0.4218 - val_accuracy: 0.7978 - val_loss: 0.4308
# Epoch 210/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8249 - loss: 0.4193 - val_accuracy: 0.8015 - val_loss: 0.4300
# Epoch 211/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8093 - loss: 0.4210 - val_accuracy: 0.7978 - val_loss: 0.4300
# Epoch 212/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8062 - loss: 0.4204 - val_accuracy: 0.8052 - val_loss: 0.4295
# Epoch 213/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8002 - loss: 0.4406 - val_accuracy: 0.7978 - val_loss: 0.4295
# Epoch 214/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8218 - loss: 0.4163 - val_accuracy: 0.8052 - val_loss: 0.4290
# Epoch 215/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.7923 - loss: 0.4327 - val_accuracy: 0.7978 - val_loss: 0.4293
# Epoch 216/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8238 - loss: 0.4000 - val_accuracy: 0.7978 - val_loss: 0.4292
# Epoch 217/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8044 - loss: 0.4188 - val_accuracy: 0.8052 - val_loss: 0.4286
# Epoch 218/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8032 - loss: 0.4177 - val_accuracy: 0.7978 - val_loss: 0.4285
# Epoch 219/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8117 - loss: 0.4143 - val_accuracy: 0.8052 - val_loss: 0.4284
# Epoch 220/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8054 - loss: 0.4269 - val_accuracy: 0.7978 - val_loss: 0.4282
# Epoch 221/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8225 - loss: 0.4130 - val_accuracy: 0.7978 - val_loss: 0.4276
# Epoch 222/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8161 - loss: 0.4179 - val_accuracy: 0.7978 - val_loss: 0.4272
# Epoch 223/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8344 - loss: 0.3935 - val_accuracy: 0.8052 - val_loss: 0.4270
# Epoch 224/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8170 - loss: 0.4132 - val_accuracy: 0.7978 - val_loss: 0.4270
# Epoch 225/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8159 - loss: 0.4100 - val_accuracy: 0.8015 - val_loss: 0.4277
# Epoch 226/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8200 - loss: 0.4076 - val_accuracy: 0.7978 - val_loss: 0.4269
# Epoch 227/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8148 - loss: 0.4199 - val_accuracy: 0.8052 - val_loss: 0.4266
# Epoch 228/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8145 - loss: 0.4132 - val_accuracy: 0.7978 - val_loss: 0.4267
# Epoch 229/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - accuracy: 0.8183 - loss: 0.4065 - val_accuracy: 0.7978 - val_loss: 0.4263
# Epoch 230/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8165 - loss: 0.4153 - val_accuracy: 0.8052 - val_loss: 0.4260
# Epoch 231/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8164 - loss: 0.4112 - val_accuracy: 0.8052 - val_loss: 0.4258
# Epoch 232/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8235 - loss: 0.3982 - val_accuracy: 0.8052 - val_loss: 0.4255
# Epoch 233/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8110 - loss: 0.4207 - val_accuracy: 0.8052 - val_loss: 0.4256
# Epoch 234/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8001 - loss: 0.4206 - val_accuracy: 0.7978 - val_loss: 0.4255
# Epoch 235/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8121 - loss: 0.4206 - val_accuracy: 0.7940 - val_loss: 0.4253
# Epoch 236/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8366 - loss: 0.4015 - val_accuracy: 0.7940 - val_loss: 0.4257
# Epoch 237/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8148 - loss: 0.4217 - val_accuracy: 0.7978 - val_loss: 0.4251
# Epoch 238/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8202 - loss: 0.4071 - val_accuracy: 0.7940 - val_loss: 0.4250
# Epoch 239/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8059 - loss: 0.4235 - val_accuracy: 0.7940 - val_loss: 0.4246
# Epoch 240/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8330 - loss: 0.4046 - val_accuracy: 0.7940 - val_loss: 0.4244
# Epoch 241/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8190 - loss: 0.4082 - val_accuracy: 0.8015 - val_loss: 0.4253
# Epoch 242/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8208 - loss: 0.4093 - val_accuracy: 0.8015 - val_loss: 0.4238
# Epoch 243/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8125 - loss: 0.4174 - val_accuracy: 0.8015 - val_loss: 0.4236
# Epoch 244/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8188 - loss: 0.4120 - val_accuracy: 0.7978 - val_loss: 0.4239
# Epoch 245/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8072 - loss: 0.4265 - val_accuracy: 0.8015 - val_loss: 0.4232
# Epoch 246/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8165 - loss: 0.4071 - val_accuracy: 0.8015 - val_loss: 0.4231
# Epoch 247/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8304 - loss: 0.4014 - val_accuracy: 0.8052 - val_loss: 0.4229
# Epoch 248/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.8115 - loss: 0.4042 - val_accuracy: 0.8015 - val_loss: 0.4229
# Epoch 249/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8232 - loss: 0.4076 - val_accuracy: 0.8015 - val_loss: 0.4224
# Epoch 250/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8233 - loss: 0.4066 - val_accuracy: 0.7978 - val_loss: 0.4223
# Epoch 251/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8068 - loss: 0.4211 - val_accuracy: 0.8015 - val_loss: 0.4220
# Epoch 252/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8110 - loss: 0.4195 - val_accuracy: 0.8052 - val_loss: 0.4214
# Epoch 253/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.7961 - loss: 0.4309 - val_accuracy: 0.8052 - val_loss: 0.4217
# Epoch 254/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8244 - loss: 0.4033 - val_accuracy: 0.8015 - val_loss: 0.4215
# Epoch 255/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8097 - loss: 0.4238 - val_accuracy: 0.8015 - val_loss: 0.4210
# Epoch 256/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7938 - loss: 0.4176 - val_accuracy: 0.8052 - val_loss: 0.4206
# Epoch 257/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8023 - loss: 0.4128 - val_accuracy: 0.8052 - val_loss: 0.4209
# Epoch 258/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8001 - loss: 0.4234 - val_accuracy: 0.8090 - val_loss: 0.4210
# Epoch 259/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8189 - loss: 0.4024 - val_accuracy: 0.8052 - val_loss: 0.4212
# Epoch 260/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8210 - loss: 0.4155 - val_accuracy: 0.8052 - val_loss: 0.4209
# Epoch 261/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8075 - loss: 0.4105 - val_accuracy: 0.8015 - val_loss: 0.4202
# Epoch 262/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8146 - loss: 0.4061 - val_accuracy: 0.8052 - val_loss: 0.4201
# Epoch 263/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8284 - loss: 0.4068 - val_accuracy: 0.8015 - val_loss: 0.4201
# Epoch 264/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8362 - loss: 0.3991 - val_accuracy: 0.8052 - val_loss: 0.4200
# Epoch 265/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8190 - loss: 0.4075 - val_accuracy: 0.8052 - val_loss: 0.4202
# Epoch 266/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8329 - loss: 0.3920 - val_accuracy: 0.8015 - val_loss: 0.4194
# Epoch 267/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8145 - loss: 0.4143 - val_accuracy: 0.8090 - val_loss: 0.4195
# Epoch 268/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8218 - loss: 0.4061 - val_accuracy: 0.8015 - val_loss: 0.4200
# Epoch 269/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8261 - loss: 0.3964 - val_accuracy: 0.8052 - val_loss: 0.4188
# Epoch 270/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8186 - loss: 0.4066 - val_accuracy: 0.8015 - val_loss: 0.4198
# Epoch 271/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8176 - loss: 0.4083 - val_accuracy: 0.8015 - val_loss: 0.4197
# Epoch 272/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8322 - loss: 0.4114 - val_accuracy: 0.8090 - val_loss: 0.4188
# Epoch 273/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8218 - loss: 0.4046 - val_accuracy: 0.8052 - val_loss: 0.4186
# Epoch 274/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8105 - loss: 0.4151 - val_accuracy: 0.8090 - val_loss: 0.4184
# Epoch 275/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8345 - loss: 0.3930 - val_accuracy: 0.8090 - val_loss: 0.4178
# Epoch 276/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8111 - loss: 0.4136 - val_accuracy: 0.8090 - val_loss: 0.4176
# Epoch 277/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8388 - loss: 0.3929 - val_accuracy: 0.8015 - val_loss: 0.4173
# Epoch 278/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8022 - loss: 0.4215 - val_accuracy: 0.8090 - val_loss: 0.4173
# Epoch 279/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8096 - loss: 0.4089 - val_accuracy: 0.8090 - val_loss: 0.4170
# Epoch 280/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8208 - loss: 0.4081 - val_accuracy: 0.8090 - val_loss: 0.4166
# Epoch 281/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8312 - loss: 0.3989 - val_accuracy: 0.8090 - val_loss: 0.4167
# Epoch 282/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8274 - loss: 0.4037 - val_accuracy: 0.8052 - val_loss: 0.4168
# Epoch 283/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8252 - loss: 0.4001 - val_accuracy: 0.8090 - val_loss: 0.4165
# Epoch 284/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8147 - loss: 0.3968 - val_accuracy: 0.8090 - val_loss: 0.4169
# Epoch 285/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - accuracy: 0.8172 - loss: 0.4061 - val_accuracy: 0.8090 - val_loss: 0.4167
# Epoch 286/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8232 - loss: 0.4141 - val_accuracy: 0.8090 - val_loss: 0.4165
# Epoch 287/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8155 - loss: 0.4084 - val_accuracy: 0.8090 - val_loss: 0.4164
# Epoch 288/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8109 - loss: 0.4146 - val_accuracy: 0.8090 - val_loss: 0.4159
# Epoch 289/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8217 - loss: 0.4099 - val_accuracy: 0.8090 - val_loss: 0.4164
# Epoch 290/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8357 - loss: 0.3874 - val_accuracy: 0.8090 - val_loss: 0.4162
# Epoch 291/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8047 - loss: 0.4246 - val_accuracy: 0.8052 - val_loss: 0.4157
# Epoch 292/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8063 - loss: 0.4163 - val_accuracy: 0.8090 - val_loss: 0.4154
# Epoch 293/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8167 - loss: 0.3934 - val_accuracy: 0.8052 - val_loss: 0.4154
# Epoch 294/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8112 - loss: 0.4150 - val_accuracy: 0.8052 - val_loss: 0.4152
# Epoch 295/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8178 - loss: 0.3940 - val_accuracy: 0.8090 - val_loss: 0.4149
# Epoch 296/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.8255 - loss: 0.4034 - val_accuracy: 0.8052 - val_loss: 0.4149
# Epoch 297/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.8335 - loss: 0.4001 - val_accuracy: 0.8090 - val_loss: 0.4144
# Epoch 298/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8271 - loss: 0.4066 - val_accuracy: 0.8090 - val_loss: 0.4140
# Epoch 299/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8330 - loss: 0.4044 - val_accuracy: 0.8090 - val_loss: 0.4136
# Epoch 300/300
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8255 - loss: 0.4122 - val_accuracy: 0.8052 - val_loss: 0.4134
# Restoring model weights from the end of the best epoch: 300.

# %%
# -------------------------------
# Evaluate the Model on Train, Validation, and Test Sets
# -------------------------------

# Evaluate on Training Set
train_loss, train_acc = model.evaluate(train_generator, verbose=1)
print("Train Accuracy: {:.2f}%".format(train_acc * 100))
print("Train Loss: {:.4f}".format(train_loss))

# Evaluate on Validation Set
val_loss, val_acc = model.evaluate(validation_generator, verbose=1)
print("Validation Accuracy: {:.2f}%".format(val_acc * 100))
print("Validation Loss: {:.4f}".format(val_loss))

# Evaluate on Test Set
test_loss, test_acc = model.evaluate(test_generator, verbose=1)
print("Test Accuracy: {:.2f}%".format(test_acc * 100))
print("Test Loss: {:.4f}".format(test_loss))

# Print summary of results
print("\n=== Model Evaluation Summary ===")
print(f"Train Accuracy:     {train_acc * 100:.2f}%")
print(f"Train Loss:         {train_loss:.4f}")
print(f"Validation Accuracy:{val_acc * 100:.2f}%")
print(f"Validation Loss:    {val_loss:.4f}")
print(f"Test Accuracy:      {test_acc * 100:.2f}%")
print(f"Test Loss:          {test_loss:.4f}")
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - accuracy: 0.8832 - loss: 0.3453
# Train Accuracy: 87.32%
# Train Loss: 0.3554
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.7741 - loss: 0.4511
# Validation Accuracy: 80.52%
# Validation Loss: 0.4134
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 745ms/step - accuracy: 0.7475 - loss: 0.5102
# Test Accuracy: 77.27%
# Test Loss: 0.4789
#
# === Model Evaluation Summary ===
# Train Accuracy:     87.32%
# Train Loss:         0.3554
# Validation Accuracy:80.52%
# Validation Loss:    0.4134
# Test Accuracy:      77.27%
# Test Loss:          0.4789

# %%
# -------------------------------
# Compute Classification Metrics
# -------------------------------
test_preds = model.predict(test_generator)
y_pred = (test_preds > 0.5).astype(int).flatten()  # Convert probabilities to binary labels
y_true = test_generator.classes

# Classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=classes))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 356ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      healthy       0.79      0.76      0.77       136
#     diseased       0.75      0.79      0.77       128
#
#     accuracy                           0.77       264
#    macro avg       0.77      0.77      0.77       264
# weighted avg       0.77      0.77      0.77       264
#
# Confusion Matrix:
# [[103  33]
#  [ 27 101]]

# %%
# -------------------------------
# Visualize Confusion Matrix
# -------------------------------
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(f"Confusion Matrix for Filter: {filter_name}")
plt.show()

# %%
# -------------------------------
# Visualize Training History
# -------------------------------
plt.figure(figsize=(12,5))

# Plot Training vs Validation Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()

# Plot Training vs Validation Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()

plt.show()

# %%
# -------------------------------
# Visualize Sample Predictions
# -------------------------------
test_images, test_labels = next(test_generator)
preds = model.predict(test_images)
pred_classes = (preds > 0.5).astype(int).flatten()
true_classes = test_labels.astype(int)

plt.figure(figsize=(12,12))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(test_images[i])
    plt.title(f"True: {classes[true_classes[i]]}\nPred: {classes[pred_classes[i]]}")
    plt.axis('off')
plt.suptitle(f"Sample Predictions for Filter: {filter_name}")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Generate predictions
test_preds = model.predict(test_generator)
y_pred = np.argmax(test_preds, axis=1)  # Convert to class indices

# Get true labels from the test generator
y_true = test_generator.classes  # These are numerical labels (0 or 1)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step

# %%
species_true = []
species_pred = []

# Extract species names correctly from filenames
for i, filename in enumerate(test_generator.filenames):
    # Example: "diseased/Papaya_diseased/leaf_123.jpg"
    parts = filename.split('/')  
    if len(parts) >= 2:  # Ensure correct structure
        species = parts[1].split('_')[0]  # Extract 'Papaya', 'Potato', 'Tomato'
        species_true.append(species)
        species_pred.append("healthy" if y_pred[i] == 1 else "diseased")  # Get model prediction

print("Sample true species:", species_true[:10])
print("Sample predicted labels:", species_pred[:10])
# Out:
# Sample true species: ['Papaya', 'Papaya', 'Papaya', 'Papaya', 'Papaya', 'Papaya', 'Papaya', 'Papaya', 'Papaya', 'Papaya']
# Sample predicted labels: ['diseased', 'diseased', 'diseased', 'diseased', 'diseased', 'diseased', 'diseased', 'diseased', 'diseased', 'diseased']

# %%
from collections import defaultdict

species_correct = defaultdict(int)
species_total = defaultdict(int)

# Count correct predictions per species
for i in range(len(species_true)):
    true_species = species_true[i]
    true_label = "healthy" if y_true[i] == 1 else "diseased"
    pred_label = species_pred[i]  # Model predicted "healthy" or "diseased"

    # Count correctly predicted cases
    if pred_label == true_label:
        species_correct[true_species] += 1
    
    species_total[true_species] += 1

# Compute accuracy per species
species_accuracy = {species: (species_correct[species] / species_total[species]) * 100 
                    for species in species_total}

# Print accuracy per plant species
print("\n=== Per-Species Accuracy ===")
for species, acc in species_accuracy.items():
    print(f"{species}: {acc:.2f}%")
# Out:
# === Per-Species Accuracy ===
# Papaya: 44.62%
# Potato: 56.76%
# Tomato: 50.00%

# %%
import matplotlib.pyplot as plt

species_list = list(species_accuracy.keys())
accuracy_list = list(species_accuracy.values())

plt.figure(figsize=(8,5))
plt.bar(species_list, accuracy_list, color=['green', 'blue', 'red'])
plt.xlabel("Plant Species")
plt.ylabel("Accuracy (%)")
plt.title("Per-Species Classification Accuracy")
plt.ylim(0, 100)
plt.show()

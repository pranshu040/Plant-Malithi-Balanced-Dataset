# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd

# %%
# -------------------------------
# Parameters
# -------------------------------
img_height, img_width = 224, 224
batch_size = 32
max_epochs = 300  # Maximum training epochs

# Adam optimizer parameters
learning_rate = 1e-4
beta_1 = 0.9
beta_2 = 0.999
epsilon = 1e-7

# Early stopping to prevent overfitting
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

# %%
# -------------------------------
# Paths & Filter Selection
# -------------------------------
dataset_path = "/kaggle/input/new-data/Balanced_dataset_augmented_new"
filter_name = "blueIR_balance"  # Change filter if needed

# Define two classes: Healthy and Diseased
classes = ["healthy", "diseased"]  # Matching your folder structure

# Construct dataset paths
filter_path = os.path.join(dataset_path, filter_name)
train_dir = os.path.join(filter_path, 'train')
validation_dir = os.path.join(filter_path, 'validation')
test_dir = os.path.join(filter_path, 'test')

# %%
# -------------------------------
# Data Generators
# -------------------------------
datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',  # Binary classification
    color_mode='rgb',  # Ensure all images are RGB
    shuffle=True
)

validation_generator = datagen.flow_from_directory(
    validation_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',  # Binary classification
    color_mode='rgb',
    shuffle=False
)

test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',  # Binary classification
    color_mode='rgb',
    shuffle=False
)
# Out:
# Found 2168 images belonging to 2 classes.
# Found 244 images belonging to 2 classes.
# Found 240 images belonging to 2 classes.

# %%
# -------------------------------
# Build the Xception Model
# -------------------------------
base_model = Xception(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom classification head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)  # Dropout for regularization
predictions = Dense(1, activation='sigmoid')(x)  # Single neuron for binary classification

# %%
# Create the full model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1 (Conv2D)     │ (None, 111, 111, 32)   │            864 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1_bn           │ (None, 111, 111, 32)   │            128 │ block1_conv1[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv1_act          │ (None, 111, 111, 32)   │              0 │ block1_conv1_bn[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2 (Conv2D)     │ (None, 109, 109, 64)   │         18,432 │ block1_conv1_act[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2_bn           │ (None, 109, 109, 64)   │            256 │ block1_conv2[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_conv2_act          │ (None, 109, 109, 64)   │              0 │ block1_conv2_bn[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv1           │ (None, 109, 109, 128)  │          8,768 │ block1_conv2_act[0][0] │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv1_bn        │ (None, 109, 109, 128)  │            512 │ block2_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv2_act       │ (None, 109, 109, 128)  │              0 │ block2_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv2           │ (None, 109, 109, 128)  │         17,536 │ block2_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_sepconv2_bn        │ (None, 109, 109, 128)  │            512 │ block2_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 55, 55, 128)    │          8,192 │ block1_conv2_act[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_pool               │ (None, 55, 55, 128)    │              0 │ block2_sepconv2_bn[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 55, 55, 128)    │            512 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_24 (Add)              │ (None, 55, 55, 128)    │              0 │ block2_pool[0][0],     │
# │                           │                        │                │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv1_act       │ (None, 55, 55, 128)    │              0 │ add_24[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv1           │ (None, 55, 55, 256)    │         33,920 │ block3_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv1_bn        │ (None, 55, 55, 256)    │          1,024 │ block3_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv2_act       │ (None, 55, 55, 256)    │              0 │ block3_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv2           │ (None, 55, 55, 256)    │         67,840 │ block3_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_sepconv2_bn        │ (None, 55, 55, 256)    │          1,024 │ block3_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 28, 28, 256)    │         32,768 │ add_24[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_pool               │ (None, 28, 28, 256)    │              0 │ block3_sepconv2_bn[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 28, 28, 256)    │          1,024 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_25 (Add)              │ (None, 28, 28, 256)    │              0 │ block3_pool[0][0],     │
# │                           │                        │                │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv1_act       │ (None, 28, 28, 256)    │              0 │ add_25[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv1           │ (None, 28, 28, 728)    │        188,672 │ block4_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv1_bn        │ (None, 28, 28, 728)    │          2,912 │ block4_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv2_act       │ (None, 28, 28, 728)    │              0 │ block4_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv2           │ (None, 28, 28, 728)    │        536,536 │ block4_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_sepconv2_bn        │ (None, 28, 28, 728)    │          2,912 │ block4_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 14, 14, 728)    │        186,368 │ add_25[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_pool               │ (None, 14, 14, 728)    │              0 │ block4_sepconv2_bn[0]… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 14, 14, 728)    │          2,912 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_26 (Add)              │ (None, 14, 14, 728)    │              0 │ block4_pool[0][0],     │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_26[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block5_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block5_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block5_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block5_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block5_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block5_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block5_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block5_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_27 (Add)              │ (None, 14, 14, 728)    │              0 │ block5_sepconv3_bn[0]… │
# │                           │                        │                │ add_26[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_27[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block6_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block6_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block6_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block6_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block6_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block6_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block6_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block6_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_28 (Add)              │ (None, 14, 14, 728)    │              0 │ block6_sepconv3_bn[0]… │
# │                           │                        │                │ add_27[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_28[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block7_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block7_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block7_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block7_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block7_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block7_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block7_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block7_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_29 (Add)              │ (None, 14, 14, 728)    │              0 │ block7_sepconv3_bn[0]… │
# │                           │                        │                │ add_28[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_29[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block8_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block8_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block8_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block8_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block8_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block8_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block8_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block8_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block8_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_30 (Add)              │ (None, 14, 14, 728)    │              0 │ block8_sepconv3_bn[0]… │
# │                           │                        │                │ add_29[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv1_act       │ (None, 14, 14, 728)    │              0 │ add_30[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv1           │ (None, 14, 14, 728)    │        536,536 │ block9_sepconv1_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv1_bn        │ (None, 14, 14, 728)    │          2,912 │ block9_sepconv1[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv2_act       │ (None, 14, 14, 728)    │              0 │ block9_sepconv1_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv2           │ (None, 14, 14, 728)    │        536,536 │ block9_sepconv2_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv2_bn        │ (None, 14, 14, 728)    │          2,912 │ block9_sepconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv3_act       │ (None, 14, 14, 728)    │              0 │ block9_sepconv2_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv3           │ (None, 14, 14, 728)    │        536,536 │ block9_sepconv3_act[0… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block9_sepconv3_bn        │ (None, 14, 14, 728)    │          2,912 │ block9_sepconv3[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_31 (Add)              │ (None, 14, 14, 728)    │              0 │ block9_sepconv3_bn[0]… │
# │                           │                        │                │ add_30[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_31[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block10_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block10_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block10_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv2          │ (None, 14, 14, 728)    │        536,536 │ block10_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv2_bn       │ (None, 14, 14, 728)    │          2,912 │ block10_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv3_act      │ (None, 14, 14, 728)    │              0 │ block10_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv3          │ (None, 14, 14, 728)    │        536,536 │ block10_sepconv3_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block10_sepconv3_bn       │ (None, 14, 14, 728)    │          2,912 │ block10_sepconv3[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_32 (Add)              │ (None, 14, 14, 728)    │              0 │ block10_sepconv3_bn[0… │
# │                           │                        │                │ add_31[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_32[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block11_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block11_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block11_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv2          │ (None, 14, 14, 728)    │        536,536 │ block11_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv2_bn       │ (None, 14, 14, 728)    │          2,912 │ block11_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv3_act      │ (None, 14, 14, 728)    │              0 │ block11_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv3          │ (None, 14, 14, 728)    │        536,536 │ block11_sepconv3_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block11_sepconv3_bn       │ (None, 14, 14, 728)    │          2,912 │ block11_sepconv3[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_33 (Add)              │ (None, 14, 14, 728)    │              0 │ block11_sepconv3_bn[0… │
# │                           │                        │                │ add_32[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_33[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block12_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block12_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block12_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv2          │ (None, 14, 14, 728)    │        536,536 │ block12_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv2_bn       │ (None, 14, 14, 728)    │          2,912 │ block12_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv3_act      │ (None, 14, 14, 728)    │              0 │ block12_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv3          │ (None, 14, 14, 728)    │        536,536 │ block12_sepconv3_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block12_sepconv3_bn       │ (None, 14, 14, 728)    │          2,912 │ block12_sepconv3[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_34 (Add)              │ (None, 14, 14, 728)    │              0 │ block12_sepconv3_bn[0… │
# │                           │                        │                │ add_33[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv1_act      │ (None, 14, 14, 728)    │              0 │ add_34[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv1          │ (None, 14, 14, 728)    │        536,536 │ block13_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv1_bn       │ (None, 14, 14, 728)    │          2,912 │ block13_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv2_act      │ (None, 14, 14, 728)    │              0 │ block13_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv2          │ (None, 14, 14, 1024)   │        752,024 │ block13_sepconv2_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_sepconv2_bn       │ (None, 14, 14, 1024)   │          4,096 │ block13_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 7, 7, 1024)     │        745,472 │ add_34[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block13_pool              │ (None, 7, 7, 1024)     │              0 │ block13_sepconv2_bn[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 7, 7, 1024)     │          4,096 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_35 (Add)              │ (None, 7, 7, 1024)     │              0 │ block13_pool[0][0],    │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv1          │ (None, 7, 7, 1536)     │      1,582,080 │ add_35[0][0]           │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv1_bn       │ (None, 7, 7, 1536)     │          6,144 │ block14_sepconv1[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv1_act      │ (None, 7, 7, 1536)     │              0 │ block14_sepconv1_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv2          │ (None, 7, 7, 2048)     │      3,159,552 │ block14_sepconv1_act[… │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv2_bn       │ (None, 7, 7, 2048)     │          8,192 │ block14_sepconv2[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block14_sepconv2_act      │ (None, 7, 7, 2048)     │              0 │ block14_sepconv2_bn[0… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 2048)           │              0 │ block14_sepconv2_act[… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 2048)           │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1)              │          2,049 │ dropout_2[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 20,863,529 (79.59 MB)
#  Trainable params: 2,049 (8.00 KB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
# -------------------------------
# Train the Model
# -------------------------------
history = model.fit(
    train_generator,
    epochs=max_epochs,
    validation_data=validation_generator,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/300
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 40s 476ms/step - accuracy: 0.5117 - loss: 0.7134 - val_accuracy: 0.4836 - val_loss: 0.6986
# Epoch 2/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - accuracy: 0.5524 - loss: 0.6845 - val_accuracy: 0.5533 - val_loss: 0.6866
# Epoch 3/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.5664 - loss: 0.6829 - val_accuracy: 0.5984 - val_loss: 0.6749
# Epoch 4/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step - accuracy: 0.5713 - loss: 0.6846 - val_accuracy: 0.6270 - val_loss: 0.6666
# Epoch 5/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.5870 - loss: 0.6667 - val_accuracy: 0.6475 - val_loss: 0.6592
# Epoch 6/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.6331 - loss: 0.6467 - val_accuracy: 0.6557 - val_loss: 0.6471
# Epoch 7/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.6232 - loss: 0.6458 - val_accuracy: 0.6557 - val_loss: 0.6424
# Epoch 8/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - accuracy: 0.6225 - loss: 0.6408 - val_accuracy: 0.6844 - val_loss: 0.6360
# Epoch 9/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.6525 - loss: 0.6399 - val_accuracy: 0.6803 - val_loss: 0.6267
# Epoch 10/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.6597 - loss: 0.6354 - val_accuracy: 0.6721 - val_loss: 0.6234
# Epoch 11/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.6757 - loss: 0.6164 - val_accuracy: 0.6762 - val_loss: 0.6161
# Epoch 12/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.6807 - loss: 0.6220 - val_accuracy: 0.6762 - val_loss: 0.6132
# Epoch 13/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.6754 - loss: 0.6144 - val_accuracy: 0.6885 - val_loss: 0.6107
# Epoch 14/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.6752 - loss: 0.6111 - val_accuracy: 0.6844 - val_loss: 0.6035
# Epoch 15/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.6828 - loss: 0.6071 - val_accuracy: 0.6844 - val_loss: 0.6017
# Epoch 16/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.6696 - loss: 0.6094 - val_accuracy: 0.6803 - val_loss: 0.5978
# Epoch 17/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.6678 - loss: 0.6173 - val_accuracy: 0.6885 - val_loss: 0.5944
# Epoch 18/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.6622 - loss: 0.6037 - val_accuracy: 0.6885 - val_loss: 0.5916
# Epoch 19/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.6935 - loss: 0.5949 - val_accuracy: 0.6967 - val_loss: 0.5914
# Epoch 20/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7108 - loss: 0.5850 - val_accuracy: 0.6967 - val_loss: 0.5860
# Epoch 21/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7122 - loss: 0.5773 - val_accuracy: 0.6926 - val_loss: 0.5842
# Epoch 22/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7084 - loss: 0.5707 - val_accuracy: 0.6844 - val_loss: 0.5793
# Epoch 23/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7129 - loss: 0.5659 - val_accuracy: 0.6844 - val_loss: 0.5766
# Epoch 24/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7029 - loss: 0.5740 - val_accuracy: 0.6885 - val_loss: 0.5763
# Epoch 25/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7115 - loss: 0.5686 - val_accuracy: 0.7049 - val_loss: 0.5754
# Epoch 26/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7086 - loss: 0.5657 - val_accuracy: 0.7008 - val_loss: 0.5731
# Epoch 27/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7327 - loss: 0.5535 - val_accuracy: 0.6926 - val_loss: 0.5690
# Epoch 28/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7078 - loss: 0.5737 - val_accuracy: 0.6885 - val_loss: 0.5670
# Epoch 29/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7242 - loss: 0.5523 - val_accuracy: 0.7008 - val_loss: 0.5672
# Epoch 30/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7005 - loss: 0.5739 - val_accuracy: 0.7131 - val_loss: 0.5654
# Epoch 31/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7340 - loss: 0.5511 - val_accuracy: 0.7090 - val_loss: 0.5640
# Epoch 32/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7024 - loss: 0.5774 - val_accuracy: 0.7049 - val_loss: 0.5635
# Epoch 33/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7362 - loss: 0.5479 - val_accuracy: 0.7049 - val_loss: 0.5598
# Epoch 34/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7255 - loss: 0.5539 - val_accuracy: 0.7090 - val_loss: 0.5594
# Epoch 35/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7312 - loss: 0.5523 - val_accuracy: 0.7090 - val_loss: 0.5601
# Epoch 36/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7165 - loss: 0.5588 - val_accuracy: 0.7049 - val_loss: 0.5603
# Epoch 37/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7382 - loss: 0.5397 - val_accuracy: 0.7090 - val_loss: 0.5561
# Epoch 38/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7139 - loss: 0.5539 - val_accuracy: 0.7090 - val_loss: 0.5556
# Epoch 39/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7512 - loss: 0.5263 - val_accuracy: 0.7090 - val_loss: 0.5539
# Epoch 40/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7332 - loss: 0.5446 - val_accuracy: 0.7049 - val_loss: 0.5529
# Epoch 41/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7420 - loss: 0.5341 - val_accuracy: 0.7131 - val_loss: 0.5502
# Epoch 42/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7471 - loss: 0.5428 - val_accuracy: 0.7049 - val_loss: 0.5511
# Epoch 43/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7348 - loss: 0.5483 - val_accuracy: 0.7172 - val_loss: 0.5530
# Epoch 44/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7544 - loss: 0.5343 - val_accuracy: 0.7131 - val_loss: 0.5461
# Epoch 45/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7393 - loss: 0.5346 - val_accuracy: 0.7172 - val_loss: 0.5496
# Epoch 46/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7403 - loss: 0.5434 - val_accuracy: 0.7213 - val_loss: 0.5440
# Epoch 47/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7481 - loss: 0.5236 - val_accuracy: 0.7049 - val_loss: 0.5456
# Epoch 48/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7375 - loss: 0.5339 - val_accuracy: 0.7172 - val_loss: 0.5465
# Epoch 49/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7548 - loss: 0.5245 - val_accuracy: 0.7172 - val_loss: 0.5430
# Epoch 50/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7665 - loss: 0.5048 - val_accuracy: 0.7090 - val_loss: 0.5401
# Epoch 51/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7444 - loss: 0.5350 - val_accuracy: 0.7213 - val_loss: 0.5415
# Epoch 52/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7341 - loss: 0.5394 - val_accuracy: 0.7172 - val_loss: 0.5408
# Epoch 53/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7343 - loss: 0.5274 - val_accuracy: 0.7254 - val_loss: 0.5409
# Epoch 54/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7450 - loss: 0.5187 - val_accuracy: 0.7254 - val_loss: 0.5412
# Epoch 55/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7614 - loss: 0.5149 - val_accuracy: 0.7213 - val_loss: 0.5375
# Epoch 56/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7573 - loss: 0.5162 - val_accuracy: 0.7295 - val_loss: 0.5369
# Epoch 57/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7361 - loss: 0.5269 - val_accuracy: 0.7131 - val_loss: 0.5340
# Epoch 58/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7562 - loss: 0.5189 - val_accuracy: 0.7213 - val_loss: 0.5346
# Epoch 59/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7581 - loss: 0.5096 - val_accuracy: 0.7254 - val_loss: 0.5351
# Epoch 60/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7593 - loss: 0.5154 - val_accuracy: 0.7254 - val_loss: 0.5346
# Epoch 61/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7444 - loss: 0.5230 - val_accuracy: 0.7254 - val_loss: 0.5342
# Epoch 62/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7444 - loss: 0.5272 - val_accuracy: 0.7254 - val_loss: 0.5322
# Epoch 63/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7557 - loss: 0.5140 - val_accuracy: 0.7254 - val_loss: 0.5326
# Epoch 64/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7704 - loss: 0.5077 - val_accuracy: 0.7254 - val_loss: 0.5327
# Epoch 65/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7566 - loss: 0.5066 - val_accuracy: 0.7295 - val_loss: 0.5305
# Epoch 66/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7507 - loss: 0.5170 - val_accuracy: 0.7295 - val_loss: 0.5304
# Epoch 67/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7494 - loss: 0.5119 - val_accuracy: 0.7336 - val_loss: 0.5300
# Epoch 68/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7612 - loss: 0.5067 - val_accuracy: 0.7336 - val_loss: 0.5300
# Epoch 69/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7460 - loss: 0.5142 - val_accuracy: 0.7336 - val_loss: 0.5279
# Epoch 70/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7683 - loss: 0.5083 - val_accuracy: 0.7336 - val_loss: 0.5309
# Epoch 71/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7675 - loss: 0.4997 - val_accuracy: 0.7336 - val_loss: 0.5289
# Epoch 72/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7788 - loss: 0.4895 - val_accuracy: 0.7336 - val_loss: 0.5288
# Epoch 73/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7268 - loss: 0.5119 - val_accuracy: 0.7336 - val_loss: 0.5284
# Epoch 74/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.7648 - loss: 0.5020 - val_accuracy: 0.7295 - val_loss: 0.5265
# Epoch 75/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7522 - loss: 0.5098 - val_accuracy: 0.7336 - val_loss: 0.5243
# Epoch 76/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7555 - loss: 0.4936 - val_accuracy: 0.7254 - val_loss: 0.5284
# Epoch 77/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7661 - loss: 0.5136 - val_accuracy: 0.7336 - val_loss: 0.5250
# Epoch 78/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7551 - loss: 0.4970 - val_accuracy: 0.7336 - val_loss: 0.5245
# Epoch 79/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7682 - loss: 0.4956 - val_accuracy: 0.7295 - val_loss: 0.5250
# Epoch 80/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7566 - loss: 0.5059 - val_accuracy: 0.7295 - val_loss: 0.5234
# Epoch 81/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7652 - loss: 0.4906 - val_accuracy: 0.7295 - val_loss: 0.5234
# Epoch 82/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7610 - loss: 0.5034 - val_accuracy: 0.7254 - val_loss: 0.5250
# Epoch 83/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7779 - loss: 0.4892 - val_accuracy: 0.7295 - val_loss: 0.5224
# Epoch 84/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7571 - loss: 0.5052 - val_accuracy: 0.7295 - val_loss: 0.5218
# Epoch 85/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7595 - loss: 0.4921 - val_accuracy: 0.7336 - val_loss: 0.5236
# Epoch 86/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7692 - loss: 0.4932 - val_accuracy: 0.7254 - val_loss: 0.5222
# Epoch 87/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7598 - loss: 0.4827 - val_accuracy: 0.7295 - val_loss: 0.5204
# Epoch 88/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7528 - loss: 0.5105 - val_accuracy: 0.7295 - val_loss: 0.5205
# Epoch 89/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7738 - loss: 0.5001 - val_accuracy: 0.7295 - val_loss: 0.5184
# Epoch 90/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7727 - loss: 0.4943 - val_accuracy: 0.7377 - val_loss: 0.5172
# Epoch 91/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7833 - loss: 0.4868 - val_accuracy: 0.7295 - val_loss: 0.5183
# Epoch 92/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7849 - loss: 0.4858 - val_accuracy: 0.7295 - val_loss: 0.5205
# Epoch 93/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7516 - loss: 0.4958 - val_accuracy: 0.7295 - val_loss: 0.5180
# Epoch 94/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7787 - loss: 0.4748 - val_accuracy: 0.7295 - val_loss: 0.5176
# Epoch 95/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7471 - loss: 0.5087 - val_accuracy: 0.7295 - val_loss: 0.5186
# Epoch 96/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7616 - loss: 0.4888 - val_accuracy: 0.7254 - val_loss: 0.5188
# Epoch 97/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7589 - loss: 0.4974 - val_accuracy: 0.7336 - val_loss: 0.5159
# Epoch 98/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7647 - loss: 0.4969 - val_accuracy: 0.7295 - val_loss: 0.5174
# Epoch 99/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7707 - loss: 0.4920 - val_accuracy: 0.7336 - val_loss: 0.5152
# Epoch 100/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7688 - loss: 0.4764 - val_accuracy: 0.7418 - val_loss: 0.5192
# Epoch 101/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7711 - loss: 0.4816 - val_accuracy: 0.7295 - val_loss: 0.5164
# Epoch 102/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7846 - loss: 0.4858 - val_accuracy: 0.7295 - val_loss: 0.5162
# Epoch 103/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7806 - loss: 0.4667 - val_accuracy: 0.7295 - val_loss: 0.5152
# Epoch 104/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7626 - loss: 0.4928 - val_accuracy: 0.7336 - val_loss: 0.5146
# Epoch 105/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7707 - loss: 0.4883 - val_accuracy: 0.7295 - val_loss: 0.5159
# Epoch 106/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7680 - loss: 0.4940 - val_accuracy: 0.7295 - val_loss: 0.5150
# Epoch 107/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7712 - loss: 0.4909 - val_accuracy: 0.7295 - val_loss: 0.5149
# Epoch 108/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7971 - loss: 0.4664 - val_accuracy: 0.7295 - val_loss: 0.5142
# Epoch 109/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7717 - loss: 0.4884 - val_accuracy: 0.7336 - val_loss: 0.5118
# Epoch 110/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7745 - loss: 0.4955 - val_accuracy: 0.7336 - val_loss: 0.5125
# Epoch 111/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7634 - loss: 0.4971 - val_accuracy: 0.7336 - val_loss: 0.5110
# Epoch 112/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7756 - loss: 0.4896 - val_accuracy: 0.7377 - val_loss: 0.5111
# Epoch 113/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7743 - loss: 0.4806 - val_accuracy: 0.7336 - val_loss: 0.5122
# Epoch 114/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7650 - loss: 0.4850 - val_accuracy: 0.7295 - val_loss: 0.5137
# Epoch 115/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7710 - loss: 0.4839 - val_accuracy: 0.7213 - val_loss: 0.5141
# Epoch 116/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7661 - loss: 0.4783 - val_accuracy: 0.7295 - val_loss: 0.5117
# Epoch 117/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7805 - loss: 0.4828 - val_accuracy: 0.7336 - val_loss: 0.5102
# Epoch 118/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7900 - loss: 0.4695 - val_accuracy: 0.7295 - val_loss: 0.5110
# Epoch 119/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7851 - loss: 0.4822 - val_accuracy: 0.7418 - val_loss: 0.5101
# Epoch 120/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8005 - loss: 0.4690 - val_accuracy: 0.7254 - val_loss: 0.5128
# Epoch 121/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8039 - loss: 0.4637 - val_accuracy: 0.7377 - val_loss: 0.5096
# Epoch 122/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7759 - loss: 0.4716 - val_accuracy: 0.7254 - val_loss: 0.5104
# Epoch 123/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7837 - loss: 0.4676 - val_accuracy: 0.7213 - val_loss: 0.5104
# Epoch 124/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7746 - loss: 0.4794 - val_accuracy: 0.7459 - val_loss: 0.5087
# Epoch 125/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7882 - loss: 0.4728 - val_accuracy: 0.7295 - val_loss: 0.5094
# Epoch 126/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7653 - loss: 0.4816 - val_accuracy: 0.7295 - val_loss: 0.5125
# Epoch 127/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7918 - loss: 0.4779 - val_accuracy: 0.7336 - val_loss: 0.5089
# Epoch 128/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7868 - loss: 0.4715 - val_accuracy: 0.7254 - val_loss: 0.5095
# Epoch 129/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7840 - loss: 0.4657 - val_accuracy: 0.7377 - val_loss: 0.5079
# Epoch 130/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7699 - loss: 0.4750 - val_accuracy: 0.7418 - val_loss: 0.5063
# Epoch 131/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7765 - loss: 0.4714 - val_accuracy: 0.7377 - val_loss: 0.5072
# Epoch 132/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7750 - loss: 0.4784 - val_accuracy: 0.7418 - val_loss: 0.5067
# Epoch 133/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7608 - loss: 0.4802 - val_accuracy: 0.7295 - val_loss: 0.5074
# Epoch 134/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7775 - loss: 0.4787 - val_accuracy: 0.7336 - val_loss: 0.5060
# Epoch 135/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7509 - loss: 0.4788 - val_accuracy: 0.7336 - val_loss: 0.5078
# Epoch 136/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7889 - loss: 0.4541 - val_accuracy: 0.7336 - val_loss: 0.5058
# Epoch 137/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7816 - loss: 0.4695 - val_accuracy: 0.7418 - val_loss: 0.5033
# Epoch 138/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7885 - loss: 0.4535 - val_accuracy: 0.7336 - val_loss: 0.5053
# Epoch 139/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7820 - loss: 0.4771 - val_accuracy: 0.7418 - val_loss: 0.5027
# Epoch 140/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7795 - loss: 0.4579 - val_accuracy: 0.7295 - val_loss: 0.5051
# Epoch 141/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7802 - loss: 0.4639 - val_accuracy: 0.7295 - val_loss: 0.5054
# Epoch 142/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7810 - loss: 0.4664 - val_accuracy: 0.7418 - val_loss: 0.5028
# Epoch 143/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7862 - loss: 0.4697 - val_accuracy: 0.7295 - val_loss: 0.5045
# Epoch 144/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7757 - loss: 0.4698 - val_accuracy: 0.7377 - val_loss: 0.5054
# Epoch 145/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7791 - loss: 0.4689 - val_accuracy: 0.7377 - val_loss: 0.5036
# Epoch 146/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7903 - loss: 0.4615 - val_accuracy: 0.7377 - val_loss: 0.5035
# Epoch 147/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7824 - loss: 0.4694 - val_accuracy: 0.7377 - val_loss: 0.5007
# Epoch 148/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7955 - loss: 0.4671 - val_accuracy: 0.7336 - val_loss: 0.5049
# Epoch 149/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7942 - loss: 0.4538 - val_accuracy: 0.7336 - val_loss: 0.5031
# Epoch 150/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7911 - loss: 0.4578 - val_accuracy: 0.7377 - val_loss: 0.5014
# Epoch 151/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7895 - loss: 0.4636 - val_accuracy: 0.7377 - val_loss: 0.5037
# Epoch 152/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8038 - loss: 0.4645 - val_accuracy: 0.7377 - val_loss: 0.5079
# Epoch 153/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7807 - loss: 0.4699 - val_accuracy: 0.7377 - val_loss: 0.5039
# Epoch 154/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8014 - loss: 0.4536 - val_accuracy: 0.7377 - val_loss: 0.5016
# Epoch 155/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7822 - loss: 0.4746 - val_accuracy: 0.7377 - val_loss: 0.5006
# Epoch 156/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7966 - loss: 0.4423 - val_accuracy: 0.7377 - val_loss: 0.5017
# Epoch 157/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.7786 - loss: 0.4587 - val_accuracy: 0.7377 - val_loss: 0.5004
# Epoch 158/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7824 - loss: 0.4586 - val_accuracy: 0.7377 - val_loss: 0.5000
# Epoch 159/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7835 - loss: 0.4595 - val_accuracy: 0.7418 - val_loss: 0.5027
# Epoch 160/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8046 - loss: 0.4542 - val_accuracy: 0.7418 - val_loss: 0.5014
# Epoch 161/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7814 - loss: 0.4594 - val_accuracy: 0.7418 - val_loss: 0.4994
# Epoch 162/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7982 - loss: 0.4551 - val_accuracy: 0.7377 - val_loss: 0.5014
# Epoch 163/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7914 - loss: 0.4554 - val_accuracy: 0.7295 - val_loss: 0.5048
# Epoch 164/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7869 - loss: 0.4609 - val_accuracy: 0.7418 - val_loss: 0.5007
# Epoch 165/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7721 - loss: 0.4847 - val_accuracy: 0.7418 - val_loss: 0.5007
# Epoch 166/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7863 - loss: 0.4718 - val_accuracy: 0.7295 - val_loss: 0.5046
# Epoch 167/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7808 - loss: 0.4601 - val_accuracy: 0.7377 - val_loss: 0.5029
# Epoch 168/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8121 - loss: 0.4362 - val_accuracy: 0.7377 - val_loss: 0.5007
# Epoch 169/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7755 - loss: 0.4603 - val_accuracy: 0.7418 - val_loss: 0.4988
# Epoch 170/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7773 - loss: 0.4649 - val_accuracy: 0.7377 - val_loss: 0.5005
# Epoch 171/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7864 - loss: 0.4662 - val_accuracy: 0.7459 - val_loss: 0.4999
# Epoch 172/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7930 - loss: 0.4641 - val_accuracy: 0.7459 - val_loss: 0.4999
# Epoch 173/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7785 - loss: 0.4597 - val_accuracy: 0.7377 - val_loss: 0.5003
# Epoch 174/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7710 - loss: 0.4622 - val_accuracy: 0.7377 - val_loss: 0.5022
# Epoch 175/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7832 - loss: 0.4586 - val_accuracy: 0.7377 - val_loss: 0.4995
# Epoch 176/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7963 - loss: 0.4578 - val_accuracy: 0.7377 - val_loss: 0.5003
# Epoch 177/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7839 - loss: 0.4557 - val_accuracy: 0.7377 - val_loss: 0.4991
# Epoch 178/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7899 - loss: 0.4676 - val_accuracy: 0.7377 - val_loss: 0.4995
# Epoch 179/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7989 - loss: 0.4554 - val_accuracy: 0.7418 - val_loss: 0.4980
# Epoch 180/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7657 - loss: 0.4788 - val_accuracy: 0.7418 - val_loss: 0.4993
# Epoch 181/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7849 - loss: 0.4487 - val_accuracy: 0.7418 - val_loss: 0.4974
# Epoch 182/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7993 - loss: 0.4368 - val_accuracy: 0.7459 - val_loss: 0.4988
# Epoch 183/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8015 - loss: 0.4493 - val_accuracy: 0.7418 - val_loss: 0.4998
# Epoch 184/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8068 - loss: 0.4416 - val_accuracy: 0.7418 - val_loss: 0.4965
# Epoch 185/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7951 - loss: 0.4477 - val_accuracy: 0.7418 - val_loss: 0.4965
# Epoch 186/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7978 - loss: 0.4468 - val_accuracy: 0.7418 - val_loss: 0.4969
# Epoch 187/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7853 - loss: 0.4482 - val_accuracy: 0.7459 - val_loss: 0.4984
# Epoch 188/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7934 - loss: 0.4399 - val_accuracy: 0.7459 - val_loss: 0.4976
# Epoch 189/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8049 - loss: 0.4492 - val_accuracy: 0.7459 - val_loss: 0.4989
# Epoch 190/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7881 - loss: 0.4506 - val_accuracy: 0.7459 - val_loss: 0.4977
# Epoch 191/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7853 - loss: 0.4655 - val_accuracy: 0.7459 - val_loss: 0.4974
# Epoch 192/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7943 - loss: 0.4436 - val_accuracy: 0.7459 - val_loss: 0.4979
# Epoch 193/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8025 - loss: 0.4469 - val_accuracy: 0.7459 - val_loss: 0.4964
# Epoch 194/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8113 - loss: 0.4381 - val_accuracy: 0.7459 - val_loss: 0.4971
# Epoch 195/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7841 - loss: 0.4556 - val_accuracy: 0.7459 - val_loss: 0.5002
# Epoch 196/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8012 - loss: 0.4496 - val_accuracy: 0.7459 - val_loss: 0.4990
# Epoch 197/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7985 - loss: 0.4509 - val_accuracy: 0.7500 - val_loss: 0.4992
# Epoch 198/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8003 - loss: 0.4335 - val_accuracy: 0.7459 - val_loss: 0.4971
# Epoch 199/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7931 - loss: 0.4418 - val_accuracy: 0.7459 - val_loss: 0.4960
# Epoch 200/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8000 - loss: 0.4449 - val_accuracy: 0.7418 - val_loss: 0.4952
# Epoch 201/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7900 - loss: 0.4436 - val_accuracy: 0.7459 - val_loss: 0.4951
# Epoch 202/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7808 - loss: 0.4645 - val_accuracy: 0.7459 - val_loss: 0.4965
# Epoch 203/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7750 - loss: 0.4668 - val_accuracy: 0.7459 - val_loss: 0.4973
# Epoch 204/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8024 - loss: 0.4421 - val_accuracy: 0.7459 - val_loss: 0.4958
# Epoch 205/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8110 - loss: 0.4389 - val_accuracy: 0.7459 - val_loss: 0.4964
# Epoch 206/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - accuracy: 0.7787 - loss: 0.4593 - val_accuracy: 0.7459 - val_loss: 0.4967
# Epoch 207/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - accuracy: 0.7821 - loss: 0.4660 - val_accuracy: 0.7459 - val_loss: 0.4967
# Epoch 208/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8175 - loss: 0.4376 - val_accuracy: 0.7418 - val_loss: 0.4949
# Epoch 209/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7959 - loss: 0.4509 - val_accuracy: 0.7459 - val_loss: 0.4960
# Epoch 210/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7945 - loss: 0.4513 - val_accuracy: 0.7418 - val_loss: 0.4960
# Epoch 211/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7910 - loss: 0.4422 - val_accuracy: 0.7459 - val_loss: 0.4967
# Epoch 212/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8100 - loss: 0.4310 - val_accuracy: 0.7459 - val_loss: 0.4965
# Epoch 213/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7847 - loss: 0.4538 - val_accuracy: 0.7500 - val_loss: 0.4967
# Epoch 214/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8209 - loss: 0.4331 - val_accuracy: 0.7418 - val_loss: 0.4947
# Epoch 215/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7942 - loss: 0.4441 - val_accuracy: 0.7459 - val_loss: 0.4949
# Epoch 216/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7845 - loss: 0.4535 - val_accuracy: 0.7541 - val_loss: 0.4972
# Epoch 217/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7791 - loss: 0.4616 - val_accuracy: 0.7459 - val_loss: 0.4949
# Epoch 218/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8002 - loss: 0.4404 - val_accuracy: 0.7500 - val_loss: 0.4959
# Epoch 219/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7939 - loss: 0.4482 - val_accuracy: 0.7459 - val_loss: 0.4946
# Epoch 220/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8035 - loss: 0.4392 - val_accuracy: 0.7459 - val_loss: 0.4938
# Epoch 221/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7812 - loss: 0.4559 - val_accuracy: 0.7459 - val_loss: 0.4946
# Epoch 222/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - accuracy: 0.8019 - loss: 0.4414 - val_accuracy: 0.7459 - val_loss: 0.4956
# Epoch 223/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7906 - loss: 0.4534 - val_accuracy: 0.7459 - val_loss: 0.4947
# Epoch 224/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7706 - loss: 0.4605 - val_accuracy: 0.7459 - val_loss: 0.4939
# Epoch 225/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7759 - loss: 0.4609 - val_accuracy: 0.7459 - val_loss: 0.4950
# Epoch 226/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7974 - loss: 0.4451 - val_accuracy: 0.7541 - val_loss: 0.4960
# Epoch 227/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7960 - loss: 0.4462 - val_accuracy: 0.7459 - val_loss: 0.4938
# Epoch 228/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.7868 - loss: 0.4602 - val_accuracy: 0.7418 - val_loss: 0.4924
# Epoch 229/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7825 - loss: 0.4576 - val_accuracy: 0.7459 - val_loss: 0.4939
# Epoch 230/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7989 - loss: 0.4306 - val_accuracy: 0.7418 - val_loss: 0.4927
# Epoch 231/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8092 - loss: 0.4418 - val_accuracy: 0.7418 - val_loss: 0.4930
# Epoch 232/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7980 - loss: 0.4264 - val_accuracy: 0.7459 - val_loss: 0.4938
# Epoch 233/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8131 - loss: 0.4451 - val_accuracy: 0.7500 - val_loss: 0.4952
# Epoch 234/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8024 - loss: 0.4397 - val_accuracy: 0.7459 - val_loss: 0.4930
# Epoch 235/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7975 - loss: 0.4505 - val_accuracy: 0.7459 - val_loss: 0.4942
# Epoch 236/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7928 - loss: 0.4357 - val_accuracy: 0.7459 - val_loss: 0.4945
# Epoch 237/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7819 - loss: 0.4541 - val_accuracy: 0.7459 - val_loss: 0.4924
# Epoch 238/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8025 - loss: 0.4448 - val_accuracy: 0.7459 - val_loss: 0.4912
# Epoch 239/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7920 - loss: 0.4456 - val_accuracy: 0.7459 - val_loss: 0.4919
# Epoch 240/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8040 - loss: 0.4387 - val_accuracy: 0.7459 - val_loss: 0.4924
# Epoch 241/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8005 - loss: 0.4416 - val_accuracy: 0.7459 - val_loss: 0.4922
# Epoch 242/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7863 - loss: 0.4542 - val_accuracy: 0.7582 - val_loss: 0.4946
# Epoch 243/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8012 - loss: 0.4425 - val_accuracy: 0.7459 - val_loss: 0.4935
# Epoch 244/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8023 - loss: 0.4439 - val_accuracy: 0.7459 - val_loss: 0.4935
# Epoch 245/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8029 - loss: 0.4359 - val_accuracy: 0.7459 - val_loss: 0.4931
# Epoch 246/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8026 - loss: 0.4406 - val_accuracy: 0.7459 - val_loss: 0.4919
# Epoch 247/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7755 - loss: 0.4587 - val_accuracy: 0.7500 - val_loss: 0.4941
# Epoch 248/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7954 - loss: 0.4384 - val_accuracy: 0.7459 - val_loss: 0.4905
# Epoch 249/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7944 - loss: 0.4459 - val_accuracy: 0.7418 - val_loss: 0.4911
# Epoch 250/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8110 - loss: 0.4297 - val_accuracy: 0.7459 - val_loss: 0.4928
# Epoch 251/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8098 - loss: 0.4299 - val_accuracy: 0.7541 - val_loss: 0.4945
# Epoch 252/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8082 - loss: 0.4323 - val_accuracy: 0.7541 - val_loss: 0.4946
# Epoch 253/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7976 - loss: 0.4398 - val_accuracy: 0.7418 - val_loss: 0.4908
# Epoch 254/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7998 - loss: 0.4465 - val_accuracy: 0.7418 - val_loss: 0.4911
# Epoch 255/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7978 - loss: 0.4346 - val_accuracy: 0.7500 - val_loss: 0.4929
# Epoch 256/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8162 - loss: 0.4208 - val_accuracy: 0.7418 - val_loss: 0.4906
# Epoch 257/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7832 - loss: 0.4515 - val_accuracy: 0.7541 - val_loss: 0.4947
# Epoch 258/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.8111 - loss: 0.4202 - val_accuracy: 0.7459 - val_loss: 0.4907
# Epoch 259/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - accuracy: 0.7951 - loss: 0.4402 - val_accuracy: 0.7459 - val_loss: 0.4924
# Epoch 260/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8171 - loss: 0.4173 - val_accuracy: 0.7459 - val_loss: 0.4926
# Epoch 261/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8039 - loss: 0.4349 - val_accuracy: 0.7459 - val_loss: 0.4925
# Epoch 262/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7949 - loss: 0.4395 - val_accuracy: 0.7459 - val_loss: 0.4921
# Epoch 263/300
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - accuracy: 0.7780 - loss: 0.4582 - val_accuracy: 0.7582 - val_loss: 0.4960
# Epoch 263: early stopping
# Restoring model weights from the end of the best epoch: 248.

# %%
# -------------------------------
# Evaluate the Model on Train, Validation, and Test Sets
# -------------------------------

# Evaluate on Training Set
train_loss, train_acc = model.evaluate(train_generator, verbose=1)
print("Train Accuracy: {:.2f}%".format(train_acc * 100))
print("Train Loss: {:.4f}".format(train_loss))

# Evaluate on Validation Set
val_loss, val_acc = model.evaluate(validation_generator, verbose=1)
print("Validation Accuracy: {:.2f}%".format(val_acc * 100))
print("Validation Loss: {:.4f}".format(val_loss))

# Evaluate on Test Set
test_loss, test_acc = model.evaluate(test_generator, verbose=1)
print("Test Accuracy: {:.2f}%".format(test_acc * 100))
print("Test Loss: {:.4f}".format(test_loss))

# Print summary of results
print("\n=== Model Evaluation Summary ===")
print(f"Train Accuracy:     {train_acc * 100:.2f}%")
print(f"Train Loss:         {train_loss:.4f}")
print(f"Validation Accuracy:{val_acc * 100:.2f}%")
print(f"Validation Loss:    {val_loss:.4f}")
print(f"Test Accuracy:      {test_acc * 100:.2f}%")
print(f"Test Loss:          {test_loss:.4f}")
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.8392 - loss: 0.3972
# Train Accuracy: 84.64%
# Train Loss: 0.3988
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.7315 - loss: 0.4863
# Validation Accuracy: 74.59%
# Validation Loss: 0.4905
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.7520 - loss: 0.4749
# Test Accuracy: 74.17%
# Test Loss: 0.4674
#
# === Model Evaluation Summary ===
# Train Accuracy:     84.64%
# Train Loss:         0.3988
# Validation Accuracy:74.59%
# Validation Loss:    0.4905
# Test Accuracy:      74.17%
# Test Loss:          0.4674

# %%
# -------------------------------
# Compute Classification Metrics
# -------------------------------
test_preds = model.predict(test_generator)
y_pred = (test_preds > 0.5).astype(int).flatten()  # Convert probabilities to binary labels
y_true = test_generator.classes

# Classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=classes))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      healthy       0.71      0.75      0.73       112
#     diseased       0.77      0.73      0.75       128
#
#     accuracy                           0.74       240
#    macro avg       0.74      0.74      0.74       240
# weighted avg       0.74      0.74      0.74       240
#
# Confusion Matrix:
# [[84 28]
#  [34 94]]

# %%
# -------------------------------
# Visualize Confusion Matrix
# -------------------------------
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title(f"Confusion Matrix for Filter: {filter_name}")
plt.show()

# %%
# -------------------------------
# Visualize Training History
# -------------------------------
plt.figure(figsize=(12,5))

# Plot Training vs Validation Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()

# Plot Training vs Validation Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()

plt.show()

# %%
# -------------------------------
# Visualize Sample Predictions
# -------------------------------
test_images, test_labels = next(test_generator)
preds = model.predict(test_images)
pred_classes = (preds > 0.5).astype(int).flatten()
true_classes = test_labels.astype(int)

plt.figure(figsize=(12,12))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(test_images[i])
    plt.title(f"True: {classes[true_classes[i]]}\nPred: {classes[pred_classes[i]]}")
    plt.axis('off')
plt.suptitle(f"Sample Predictions for Filter: {filter_name}")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Generate predictions
test_preds = model.predict(test_generator)
y_pred = np.argmax(test_preds, axis=1)  # Convert to class indices

# Get true labels from the test generator
y_true = test_generator.classes  # These are numerical labels (0 or 1)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step

# %%
species_true = []
species_pred = []

# Extract species names correctly from filenames
for i, filename in enumerate(test_generator.filenames):
    # Example: "diseased/Papaya_diseased/leaf_123.jpg"
    parts = filename.split('/')  
    if len(parts) >= 2:  # Ensure correct structure
        species = parts[1].split('_')[0]  # Extract 'Papaya', 'Potato', 'Tomato'
        species_true.append(species)
        species_pred.append("healthy" if y_pred[i] == 1 else "diseased")  # Get model prediction

print("Sample true species:", species_true[:10])
print("Sample predicted labels:", species_pred[:10])
# Out:
# Sample true species: ['Papaya', 'Papaya', 'Papaya', 'Papaya', 'Papaya', 'Potato', 'Potato', 'Potato', 'Potato', 'Potato']
# Sample predicted labels: ['diseased', 'diseased', 'diseased', 'diseased', 'diseased', 'diseased', 'diseased', 'diseased', 'diseased', 'diseased']

# %%
from collections import defaultdict

species_correct = defaultdict(int)
species_total = defaultdict(int)

# Count correct predictions per species
for i in range(len(species_true)):
    true_species = species_true[i]
    true_label = "healthy" if y_true[i] == 1 else "diseased"
    pred_label = species_pred[i]  # Model predicted "healthy" or "diseased"

    # Count correctly predicted cases
    if pred_label == true_label:
        species_correct[true_species] += 1
    
    species_total[true_species] += 1

# Compute accuracy per species
species_accuracy = {species: (species_correct[species] / species_total[species]) * 100 
                    for species in species_total}

# Print accuracy per plant species
print("\n=== Per-Species Accuracy ===")
for species, acc in species_accuracy.items():
    print(f"{species}: {acc:.2f}%")
# Out:
# === Per-Species Accuracy ===
# Papaya: 12.20%
# Potato: 56.76%
# Tomato: 50.00%

# %%
import matplotlib.pyplot as plt

species_list = list(species_accuracy.keys())
accuracy_list = list(species_accuracy.values())

plt.figure(figsize=(8,5))
plt.bar(species_list, accuracy_list, color=['green', 'blue', 'red'])
plt.xlabel("Plant Species")
plt.ylabel("Accuracy (%)")
plt.title("Per-Species Classification Accuracy")
plt.ylim(0, 100)
plt.show()
